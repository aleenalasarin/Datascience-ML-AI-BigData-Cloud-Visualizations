# %% [markdown]
# <a href="https://colab.research.google.com/github/aleenalasarin/Machine-Learning-Project/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# seaborn is used for visualization
# in seaborn there are data set available for study purpose
# inside seaborn library a dataset is called tips
import seaborn as sns
df=sns.load_dataset('tips') #tips file load(from seaborn library)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# restaurant data set(predicting tip)
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
# corelation

# we can only calculate corelation between numerical values
# corelation higher value-1
# lower value-majority 0,rare case negative(-)
# we can identify which column is important or not important by looking corelation
# how one column is related to another column  =====>corelation
# corelation between same column====>1

df.corr()  #generates numerical columns
# Out:
# <ipython-input-5-b242e2e6a20d>:10: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()  #generates numerical columns
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# here totalbill efeects tip mostly  ====>(when total bill inc tip inc)
# we can drop the not important features  (while working in large file)

# %%
# heatmap
# plotting corelation graphically we use heatmap

sns.heatmap(df.corr())  #we draw it using seaborn
# by looking color combination we identify it
# Out:
# <ipython-input-7-43f15577729c>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())  #we draw it using seaborn
# <Axes: >

# %%
# joint plot

# can draw for numerical column only
# same as scatter plot

sns.jointplot(x='tip',y='total_bill',data=df)
# tip x-axis.y axis total_bill
# output as scatter plot but it also generates histogram

# %%
# tip size
sns.jointplot(x='tip',y='size',data=df,kind='reg')  #we can plot(draw) regression line also with it

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
# pair plot

# possible only for numerical columns
# same concept as subplot
# in pair plot we can plot all combined

sns.pairplot(df)

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
# we can pass a object to pair plot using hue

sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='day')

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.pairplot(df,hue='time')

# %%
# count plot

# we can calculate count and graphically visualize it
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='time',data=df,color='r')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='day',data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
# we can also use hue in countplot
sns.countplot(x='sex',data=df,hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex',data=df,hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex',data=df,hue='time')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# Barplot
# we want x and y for bar plot
sns.barplot(x='total_bill',y='day',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
# Boxplot
# lowest value at bottom
# 25percentile,50percentile,75percentile
# highest value at top
# the circles above the top highest value is called outliers
# wrong datas is called outliers (technical name is outliers)
# if the given data has wrong format then it is called outliers
# by drawing Boxplot we can find the outliers
sns.boxplot(x='smoker',y='total_bill',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
# percentile

# q1:25 percentile    q2:50 percentile    q3:75 percentile
# outliers

# %%
# 3,5,7,1,1,8,4,6

# to find 25,50,75 percentile

# first sort the data in ascending order
# 1,1,3,4,5,6,7,8

# calculate the median of the sorted data
# if it is even value make it to two parts

# part1       part2
# 1,1,3,4     5,6,7,8
# median=4+5/2=4.5

# median is q2:50 percentile

# q1 is calculated as:
# calculate the median of part1
# 1,1,3,4
# q1=3+1/2=2
# q1:25 percentile

# q3 is calculated as
# calculate the median of part2
# 5,6,7,8
# q3=6+7/2=6.5
# q3:75 percentile

# to find outliers first we calculate IQR(inter quartile range)
# equation
# IQR=q3-q1
# 6.5-2=4.5//
# 4.5 is IQR

# based on IQR we find outliers
# outliers occurs at most highest(top) and at most lowest(bootom)

# equation for top
# (1.5*IQR)+q3
# (1.5*4.5)+6.5 = 13.25//
# above 13.25 value are outliers

# equatiom for bottom
# q1-(1.5*IQR)
# 2-(1.5*4.5) = -4.75//
# if a value is below -4.75 that value will be ouliers
